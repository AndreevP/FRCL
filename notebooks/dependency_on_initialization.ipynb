# %%
import sys
sys.path.append("..")
from frcl.experiments.pipeline import BaselineTrainDemo, FRCLTrainDemo
from frcl.tasks import SplitMnistTask, PermutedMnistTask
import seaborn as sns
sns.set()
import matplotlib.pyplot as plt
from frcl.experiments.pipeline import FRCLStatTrace

# %%
n_tasks = 2
task = PermutedMnistTask(n_tasks)
frcl_pipeline = FRCLStatTrace(task, n_repeat=1, device='cpu', init_mu_sigma=1.0,
                              n_epochs=4, lr=1e-4, batch_size=64, n_inducing=10, n_classes=10)
frcl_pipeline.run()
# Out:
# N tasks: 2, Epoch 3
# ../frcl/frcl.py:376: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   predicted += self.pred_func(torch.stack(sample, axis=1))
# [[<frcl.experiments.estimators.AccuracyTasksEstimator at 0x7fe1e6af6eb8>]]

# %%
n_tasks = 2
task = PermutedMnistTask(n_tasks)
frcl_pipeline = FRCLStatTrace(task, n_repeat=1, device='cpu', init_mu_sigma=0.1,
                              n_epochs=4, lr=1e-4, batch_size=64, n_inducing=10, n_classes=10)
frcl_pipeline.run()
# Out:
# N tasks: 2, Epoch 3
# ../frcl/frcl.py:376: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   predicted += self.pred_func(torch.stack(sample, axis=1))
# [[<frcl.experiments.estimators.AccuracyTasksEstimator at 0x7fe1e7ef1d68>]]
